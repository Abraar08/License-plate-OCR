# %%
import os
import cv2
from jiwer import cer
import numpy as np

# %%
image = cv2.imread(r"C:\Users\moham\ocr_task\plate_images\1UK3PP.jpg", cv2.IMREAD_COLOR)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# threshold the image using Otsu's thresholding method
thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]

# %%
! pip uninstall opencv-python

# %%
plt.imshow(thresh)
plt.show()

# %%
def preprocess(input_img):
    imgBlurred = cv2.GaussianBlur(input_img, (7, 7), 0) # old window was (5,5)
    gray = cv2.cvtColor(imgBlurred, cv2.COLOR_BGR2GRAY) # convert to gray
    sobelx = cv2.Sobel(gray, cv2.CV_8U, 1, 0, ksize=3) # sobelX to get the vertical edges
    ret2, threshold_img = cv2.threshold(sobelx, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

    element = cv2.getStructuringElement(shape=cv2.MORPH_RECT, ksize=(22, 3))
    morph_img_threshold = threshold_img.copy()
    cv2.morphologyEx(src=threshold_img, op=cv2.MORPH_CLOSE, kernel=element, dst=morph_img_threshold)
    return morph_img_threshold

# %%
prep = preprocess(image)

plt.imshow(prep)
plt.show()

# %%
img1 = cv2.imread(r"C:\Users\moham\ocr_task\plate_images\1UK3PP.jpg")

# %%
img = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)

# %%
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY)

# %%
cv2.imshow('Binary Threshold', thresh1)
cv2.waitKey(0)

# %%
cv2.imshow("test", img1)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread(r"C:\Users\moham\ocr_task\plate_images\1UK3PP.jpg", cv2.IMREAD_GRAYSCALE)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
ret, thresh1 = cv2.threshold(image, 100, 255, cv2.THRESH_BINARY)

# ret2,th2 = cv2.threshold(image,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.imshow(thresh1)
plt.show()

# %%
image = cv2.imread(r"C:\Users\moham\ocr_task\plate_images\1UK3PP.jpg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# threshold the image using Otsu's thresholding method
# thresh = cv2.threshold(image, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]

ret, thresh1 = cv2.threshold(image, 120, 255, cv2.THRESH_BINARY)
cv2.imshow("Otsu", thresh1)

# %%
dist = cv2.distanceTransform(thresh, cv2.DIST_L2, 5)
dist = cv2.normalize(dist, dist, 0, 1.0, cv2.NORM_MINMAX)
dist = (dist * 255).astype("uint8")

# %%
ret, thresh2 = cv2.threshold(dist, 40, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(thresh2)
plt.show()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
img = cv2.GaussianBlur(gray,(3,3),0)
laplacian = cv2.Laplacian(img,cv2.CV_64F)
cv2.imshow("GRAY",gray)
plt.show()

# %%
cv2.COLOR

# %%
kernel = np.ones((3, 3), np.uint8)
dilate_img = cv2.dilate(thresh1, kernel) 
erode_img = cv2.erode(thresh1, kernel)
# erode_img = cv2.erode(dilate_img, kernel)

# %%
plt.imshow(erode_img)
plt.show()

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

text = pytesseract.image_to_string(erode_img)

text
# Out:
# ''

# %%
import imutils

# %%
img = imutils.resize(img, width=300 )

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("greyed image", gray_image)
cv2.waitKey(0)

# %%
gray_image = cv2.bilateralFilter(gray_image, 11, 17, 17)

# %%
edged = cv2.Canny(gray_image, 30, 200)
